# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/historical_automobile_sales (1).csv")

# %%
df
# Out:
#            Date  Year Month  Recession  Consumer_Confidence  \
# 0     1/31/1980  1980   Jan          1               108.24
# 1     2/29/1980  1980   Feb          1                98.75
# 2     3/31/1980  1980   Mar          1               107.48
# 3     4/30/1980  1980   Apr          1               115.01
# 4     5/31/1980  1980   May          1                98.72
# ..          ...   ...   ...        ...                  ...
# 523   8/31/2023  2023   Aug          0               103.36
# 524   9/30/2023  2023   Sep          0               101.55
# 525  10/31/2023  2023   Oct          0               124.66
# 526  11/30/2023  2023   Nov          0                97.09
# 527  12/31/2023  2023   Dec          0                95.92
#
#      Seasonality_Weight      Price  Advertising_Expenditure  Competition  \
# 0                  0.50  27483.571                     1558            7
# 1                  0.75  24308.678                     3048            4
# ...

# %%
df1 = df.groupby("Year")["Automobile_Sales"].mean().reset_index()

# %%
df1
# Out:
#     Year  Automobile_Sales
# 0   1980        678.950000
# 1   1981        633.408333
# 2   1982        631.150000
# 3   1983       2889.350000
# 4   1984       2972.250000
# 5   1985       3176.133333
# 6   1986       2341.133333
# 7   1987       2288.166667
# 8   1988       3074.500000
# 9   1989       3247.608333
# 10  1990        917.275000
# 11  1991        655.891667
# 12  1992       1647.700000
# 13  1993       2023.250000
# 14  1994       2554.825000
# 15  1995       4300.250000
# 16  1996       2295.208333
# 17  1997       2790.241667
# 18  1998       2994.891667
# 19  1999       2562.683333
# 20  2000       1286.791667
# 21  2001        692.133333
# 22  2002       1783.216667
# 23  2003       2628.991667
# 24  2004       3148.883333
# 25  2005       3076.566667
# 26  2006       2557.650000
# 27  2007       2727.166667
# 28  2008       1289.550000
# 29  2009        631.691667
# 30  2010       2308.600000
# 31  2011       3326.300000
# 32  2012       2782.216667
# ...

# %%
plt.plot(df1["Year"],df1["Automobile_Sales"],marker="o",color="green")

# %%
# in 1995 there is a heighest sale is noticable after that the chart show less frequency

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Date"]
# Out:
# 0     1980-01-31
# 1     1980-02-29
# 2     1980-03-31
# 3     1980-04-30
# 4     1980-05-31
#          ...
# 523   2023-08-31
# 524   2023-09-30
# 525   2023-10-31
# 526   2023-11-30
# 527   2023-12-31
# Name: Date, Length: 528, dtype: datetime64[ns]

# %%
#filter data for recession periods
recession_d = df[df["Recession"] == 1]
# groupby
df3 = recession_d.groupby(["Year","Vehicle_Type"])["Automobile_Sales"].sum().reset_index()
df3
# Out:
#     Year     Vehicle_Type  Automobile_Sales
# 0   1980  Mediumfamilycar            2882.5
# 1   1980  Smallfamiliycar            2085.7
# 2   1980    Supperminicar            3179.2
# 3   1981  Mediumfamilycar            1885.2
# 4   1981  Smallfamiliycar            3192.1
# 5   1981    Supperminicar            2523.6
# 6   1982  Mediumfamilycar            5062.9
# 7   1982  Smallfamiliycar            2408.9
# 8   1982           Sports             102.0
# 9   1983  Smallfamiliycar             589.0
# 10  1990  Mediumfamilycar            1979.2
# 11  1990  Smallfamiliycar            4404.8
# 12  1990    Supperminicar             754.8
# 13  1991     Executivecar             564.0
# 14  1991  Mediumfamilycar            3210.7
# 15  1991  Smallfamiliycar            1495.8
# 16  1991    Supperminicar            2600.2
# 17  1992  Mediumfamilycar            1340.1
# 18  1992    Supperminicar             686.1
# 19  2000  Mediumfamilycar            1966.8
# ...

# %%
sns.barplot(data=df3,x ="Year" ,y="Automobile_Sales",hue="Vehicle_Type")
# Out:
# <Axes: xlabel='Year', ylabel='Automobile_Sales'>

# %%
#filter data for recession periods
#recession_d = df[df["Recession"] == 1]
# groupby
#df3 = recession_d.groupby(["Year","Vehicle_Type"])["Automobile_Sales"].sum().reset_index()
#df3

# %%
recession_data =  df[df["Recession"] == 1]
non_recession =  df[df["Recession"] == 0]

df4 = df.groupby(["Year","Recession", "Vehicle_Type"])["Automobile_Sales"].mean().reset_index()
df4
# Out:
#      Year  Recession     Vehicle_Type  Automobile_Sales
# 0    1980          1  Mediumfamilycar        720.625000
# 1    1980          1  Smallfamiliycar        695.233333
# 2    1980          1    Supperminicar        635.840000
# 3    1981          1  Mediumfamilycar        628.400000
# 4    1981          1  Smallfamiliycar        638.420000
# ..    ...        ...              ...               ...
# 195  2022          0           Sports       1532.166667
# 196  2023          0     Executivecar       1579.600000
# 197  2023          0  Smallfamiliycar       2131.700000
# 198  2023          0           Sports       3100.250000
# 199  2023          0    Supperminicar       3208.050000
#
# [200 rows x 4 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Recession         10 non-null     int64
#  1   Vehicle_Type      10 non-null     object
#  2   Automobile_Sales  10 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 372.0+ bytes

# %%
sns.barplot(data=df4,x = "Year", y = "Automobile_Sales", hue = "Vehicle_Type",ci = None)
plt.title("Automobile Sales Trend per Vehicle Type (Barplot)")
plt.xlabel("Year")
plt.ylabel("Automobile Sales")
plt.legend(title="Vehicle Type")
plt.xticks(rotation=90)


plt.show()
# Out:
# /tmp/ipython-input-59-1183770241.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df4,x = "Year", y = "Automobile_Sales", hue = "Vehicle_Type",ci = None)

# %%
df5 = df.groupby(["Recession", "Vehicle_Type"])["Automobile_Sales"].mean().reset_index()
df5
# Out:
#    Recession     Vehicle_Type  Automobile_Sales
# 0          0     Executivecar       2686.436232
# 1          0  Mediumfamilycar       2981.501935
# 2          0  Smallfamiliycar       2752.658140
# 3          0           Sports       2910.636264
# 4          0    Supperminicar       2495.242222
# 5          1     Executivecar        564.000000
# 6          1  Mediumfamilycar        674.847619
# 7          1  Smallfamiliycar        650.733333
# 8          1           Sports        170.333333
# 9          1    Supperminicar        659.270968

# %%
#Q 4: Now you want to compare the sales of different vehicle types

sns.barplot(data=df4, x="Vehicle_Type", y="Automobile_Sales", hue="Recession")
plt.xticks(rotation=60)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Mediumfamilycar'),
#   Text(1, 0, 'Smallfamiliycar'),
#   Text(2, 0, 'Supperminicar'),
#   Text(3, 0, 'Sports'),
#   Text(4, 0, 'Executivecar')])
